# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ageDataset = pd.read_csv('Data/ageDatasetV3(Preprocessed).csv')
ageDataset.describe()
# Out:
#           Birth year     Death year   Age of death
# count  760680.000000  760680.000000  760680.000000
# mean     1865.328832    1935.150389      69.821557
# std       107.551111     110.893258      16.429528
# min     -2284.000000   -2200.000000       0.000000
# 25%      1846.000000    1913.000000      61.000000
# 50%      1894.000000    1965.000000      72.000000
# 75%      1922.000000    2000.000000      82.000000
# max      2016.000000    2021.000000     137.000000

# %%
ageDataset
# Out:
#                Id                     Name  \
# 0             Q42            Douglas Adams
# 1             Q91          Abraham Lincoln
# 2            Q272              Paul Morand
# 3            Q296             Claude Monet
# 4            Q297          Diego Velázquez
# ...           ...                      ...
# 760675  Q77218559             Gustav Siber
# 760676  Q77247326    Marie-Fortunée Besson
# 760677  Q77249818       Diether Todenhagen
# 760678  Q77253909  Reginald Oswald Pearson
# 760679  Q77254864             Horst Lerche
#
#                                         Short description       Gender  \
# 0                             English writer and humorist         Male
# 1         16th president of the United States (1809-1865)         Male
# 2                                           French writer         Male
# 3                French impressionist painter (1840-1926)         Male
# 4                             Spanish painter (1599-1660)         Male
# ...                                                   ...          ...
# 760675                      entrepreneur from Switzerland         Male
# 760676                            Frans model (1907-1996)  Unspecified
# 760677  German navy officer and world war II U-boat co...  Unspecified
# 760678  English artist, working in stained glass, prin...         Male
# 760679                                     German painter         Male
#
#                          Country          Occupation  Birth year  Death year  \
# 0                 United Kingdom              Artist        1952        2001
# 1       United States of America          Politician        1809        1865
# 2                         France              Artist        1888        1976
# 3                         France              Artist        1840        1926
# 4                          Spain              Artist        1599        1660
# ...                          ...                 ...         ...         ...
# 760675               Switzerland        Entrepreneur        1857        1924
# 760676                    France       Tailor; model        1907        1996
# 760677                   Germany  Military personnel        1920        1944
# 760678            United Kingdom              Artist        1887        1915
# 760679                   Germany              Artist        1938        2017
#
#        Manner of death  Age of death          CountryCoordinate  \
# 0       natural causes            49           ['(54.6, -2.0)']
# 1             homicide            56  ['(39.828175, -98.5795)']
# 2          Unspecified            88            ['(47.0, 2.0)']
# 3       natural causes            86            ['(47.0, 2.0)']
# 4          Unspecified            61           ['(40.2, -3.5)']
# ...                ...           ...                        ...
# 760675     Unspecified            67  ['(46.798562, 8.231973)']
# 760676     Unspecified            89            ['(47.0, 2.0)']
# 760677     Unspecified            24           ['(51.0, 10.0)']
# 760678     Unspecified            28           ['(54.6, -2.0)']
# 760679     Unspecified            79           ['(51.0, 10.0)']
#
#        AssociatedModernCountry
# 0           ['United Kingdom']
# 1            ['United States']
# 2                   ['France']
# 3                   ['France']
# 4                    ['Spain']
# ...                        ...
# 760675         ['Switzerland']
# 760676              ['France']
# 760677             ['Germany']
# 760678      ['United Kingdom']
# 760679             ['Germany']
#
# [760680 rows x 12 columns]

# %%
def convert(string):
    li = list(string[1:-1].replace("'", "").split(","))
    # list(string.split("," , 1))
    return li

def convert2(string):
    li = list(string[0:-1].replace("'", "").split(";"))
    # list(string.split("," , 1))
    return li
# remove ['']
condition = ageDataset['AssociatedModernCountry'].apply(lambda x: x != "['']")
subset_df = ageDataset[condition]

# remove []
condition = subset_df['AssociatedModernCountry'].apply(lambda x: x != "[]")
subset_df = subset_df[condition]

# Get ones with list length 1 
condition = subset_df['AssociatedModernCountry'].apply(lambda x: len(convert(x)) == 1)
subset_df = subset_df[condition]

# Fill Na's with "Unspecified"
subset_df = subset_df.fillna('Unspecified')

# Remove duplicates
subset_df.drop_duplicates(subset = "Id", keep = "first", inplace = True)

# Cast to int
subset_df["Birth year"] = subset_df['Birth year'].astype(int)
subset_df["Death year"] = subset_df['Death year'].astype(int)
subset_df["Age of death"] = subset_df['Age of death'].astype(int)

subset_df
# Out:
#                Id                     Name  \
# 0             Q42            Douglas Adams
# 1             Q91          Abraham Lincoln
# 2            Q272              Paul Morand
# 3            Q296             Claude Monet
# 4            Q297          Diego Velázquez
# ...           ...                      ...
# 760675  Q77218559             Gustav Siber
# 760676  Q77247326    Marie-Fortunée Besson
# 760677  Q77249818       Diether Todenhagen
# 760678  Q77253909  Reginald Oswald Pearson
# 760679  Q77254864             Horst Lerche
#
#                                         Short description       Gender  \
# 0                             English writer and humorist         Male
# 1         16th president of the United States (1809-1865)         Male
# 2                                           French writer         Male
# 3                French impressionist painter (1840-1926)         Male
# 4                             Spanish painter (1599-1660)         Male
# ...                                                   ...          ...
# 760675                      entrepreneur from Switzerland         Male
# 760676                            Frans model (1907-1996)  Unspecified
# 760677  German navy officer and world war II U-boat co...  Unspecified
# 760678  English artist, working in stained glass, prin...         Male
# 760679                                     German painter         Male
#
#                          Country          Occupation  Birth year  Death year  \
# 0                 United Kingdom              Artist        1952        2001
# 1       United States of America          Politician        1809        1865
# 2                         France              Artist        1888        1976
# 3                         France              Artist        1840        1926
# 4                          Spain              Artist        1599        1660
# ...                          ...                 ...         ...         ...
# 760675               Switzerland        Entrepreneur        1857        1924
# 760676                    France       Tailor; model        1907        1996
# 760677                   Germany  Military personnel        1920        1944
# 760678            United Kingdom              Artist        1887        1915
# 760679                   Germany              Artist        1938        2017
#
#        Manner of death  Age of death          CountryCoordinate  \
# 0       natural causes            49           ['(54.6, -2.0)']
# 1             homicide            56  ['(39.828175, -98.5795)']
# 2          Unspecified            88            ['(47.0, 2.0)']
# 3       natural causes            86            ['(47.0, 2.0)']
# 4          Unspecified            61           ['(40.2, -3.5)']
# ...                ...           ...                        ...
# 760675     Unspecified            67  ['(46.798562, 8.231973)']
# 760676     Unspecified            89            ['(47.0, 2.0)']
# 760677     Unspecified            24           ['(51.0, 10.0)']
# 760678     Unspecified            28           ['(54.6, -2.0)']
# 760679     Unspecified            79           ['(51.0, 10.0)']
#
#        AssociatedModernCountry
# 0           ['United Kingdom']
# 1            ['United States']
# 2                   ['France']
# 3                   ['France']
# 4                    ['Spain']
# ...                        ...
# 760675         ['Switzerland']
# 760676              ['France']
# 760677             ['Germany']
# 760678      ['United Kingdom']
# 760679             ['Germany']
#
# [760680 rows x 12 columns]

# %%
print(len(subset_df["Id"].unique()))
a, b = np.unique(subset_df["Id"].values.tolist(), return_counts = True)
results = a[b > 1]
# Out:
# 760680

# %%
#subset_df.to_csv('ageDatasetV3(PreProcessed).csv', index=False)

# %%
print("Unique old countries: ",len(subset_df["Country"].unique()))
print("Unique modern countries: ", len(subset_df["AssociatedModernCountry"].unique()))
# Out:
# Unique old countries:  469
# Unique modern countries:  200

# %%
# Finding duplicates 
subset_df["Id"].value_counts()[subset_df["Id"].value_counts() > 1].index.tolist()
# Out:
# []

# %%
# Checking conditions
subset_df[subset_df["Id"] == "Q21604253"]
# Out:
#                Id                  Name  \
# 669925  Q21604253  August Mercadé Ramon
#
#                                    Short description Gender Country  \
# 669925  Spanish economist and journalist (1909-1967)   Male   Spain
#
#             Occupation  Birth year  Death year Manner of death  Age of death  \
# 669925  Businessperson        1909        1967     Unspecified            58
#
#        CountryCoordinate AssociatedModernCountry
# 669925  ['(40.2, -3.5)']               ['Spain']

# %%
# Order by birth year
subset_df = subset_df.sort_values(by=['Birth year'])

# %%
subset_df
# Out:
#                Id           Name  \
# 306         Q6198        Pepi II
# 75794     Q712524   Seth Meribre
# 94803     Q981363         Yi Yin
# 27843     Q157966    Amenhotep I
# 27840     Q157899   Thutmose III
# ...           ...            ...
# 330615   Q5047690  Caryl Rusbult
# 659908  Q20900441     Alan Kurdi
# 744816  Q60186000    Bella Watts
# 744817  Q60186041  Celeste Watts
# 746739  Q60710025  Julen Roselló
#
#                                         Short description       Gender  \
# 306     Egyptian pharaoh of the Sixth dynasty for the ...         Male
# 75794                          ancient Egyptian sovereign         Male
# 94803                                  Chinese chancellor         Male
# 27843   Second Pharaoh of the Eighteenth dynasty of Egypt         Male
# 27840    sixth Egyptian Pharaoh of the Eighteenth Dynasty         Male
# ...                                                   ...          ...
# 330615                                  American academic       Female
# 659908  three-year-old who died from capsized boat Aug...         Male
# 744816                          American victim of murder  Unspecified
# 744817                          American victim of murder  Unspecified
# 746739                                    accident victim  Unspecified
#
#                            Country    Occupation  Birth year  Death year  \
# 306                  Ancient Egypt  Statesperson       -2284       -2200
# 75794                Ancient Egypt     Sovereign       -1750       -1700
# 94803                Shang dynasty    Politician       -1648       -1549
# 27843                Ancient Egypt  Statesperson       -1550       -1503
# 27840                Ancient Egypt  Statesperson       -1481       -1425
# ...                            ...           ...         ...         ...
# 330615  Kingdom of the Netherlands   Unspecified        2010        2010
# 659908                       Syria   Unspecified        2012        2015
# 744816    United States of America   Unspecified        2014        2018
# 744817    United States of America   Unspecified        2015        2018
# 746739                       Spain   Unspecified        2016        2019
#
#        Manner of death  Age of death                CountryCoordinate  \
# 306        Unspecified            84                 ['(29.8, 31.3)']
# 75794      Unspecified            50                 ['(29.8, 31.3)']
# 94803      Unspecified            99       ['(36.12083333, 114.325)']
# 27843      Unspecified            47                 ['(29.8, 31.3)']
# 27840      Unspecified            56                 ['(29.8, 31.3)']
# ...                ...           ...                              ...
# 330615  natural causes             0  ['(52.366666666, 4.883333333)']
# 659908        accident             3       ['(35.216667, 38.583333)']
# 744816        homicide             4        ['(39.828175, -98.5795)']
# 744817        homicide             3        ['(39.828175, -98.5795)']
# 746739        accident             3                 ['(40.2, -3.5)']
#
#        AssociatedModernCountry
# 306                  ['Egypt']
# 75794                ['Egypt']
# 94803                ['China']
# 27843                ['Egypt']
# 27840                ['Egypt']
# ...                        ...
# 330615         ['Netherlands']
# 659908               ['Syria']
# 744816       ['United States']
# 744817       ['United States']
# 746739               ['Spain']
#
# [760680 rows x 12 columns]

# %% [markdown]
# # Skip from here

# %%
# Count different values for manner of death and occupation
subset_df["Manner of death"].value_counts()
# make occupation into a list
subset_df["Occupation"] = subset_df["Occupation"].apply(lambda x: convert(x))

# count count every different occupation 
occupation = []
for i in subset_df["Occupation"]:
    occupation.extend(i)
occupation = np.unique(occupation)
print("Number of unique occupations: ", len(occupation))
# count the appearances of every occupation
occupation_count = []
for i in occupation:
    occupation_count.append(subset_df["Occupation"].apply(lambda x: i in x).sum())
# sort the occupations by their count
occupation = np.array(occupation)
occupation_count = np.array(occupation_count)
occupation = occupation[np.argsort(occupation_count)[::-1]]
occupation_count = occupation_count[np.argsort(occupation_count)[::-1]]
# plot the occupations
plt.figure(figsize=(20,10))
plt.bar(occupation[:20], occupation_count[:20])
plt.xticks(rotation=90)
plt.title("Top 20 occupations")
plt.show()

# %%
#find correlation between occupation and manner of death
occupation_manner = []
for i in occupation:
    occupation_manner.append(subset_df[subset_df["Occupation"].apply(lambda x: i in x)]["Manner of death"].value_counts())


occupation_manner_df = pd.DataFrame(occupation_manner)

# %%
#drop Unspectified
occupation_manner_df = occupation_manner_df.drop("Unspecified", axis = 1)

#plot the correlation
plt.figure(figsize=(20,10))
plt.imshow(occupation_manner_df, cmap='hot', interpolation='nearest')
plt.colorbar()
plt.title("Correlation between manner of death and occupation")
plt.show()

# %%
#drop unspecifed from manner of death and occupation
subset_df = subset_df[subset_df["Manner of death"] != "Unspecified"]
subset_df = subset_df[subset_df["Occupation"].apply(lambda x: "Unspecified" not in x)]
print("Number of rows: ", len(subset_df))
print("Number of unique occupations: ", len(np.unique(occupation)))
print("Number of unique manner of death: ", len(np.unique(subset_df["Manner of death"])))
#find correlation between occupation and manner of death
occupation_manner = []
for i in occupation:
    occupation_manner.append(subset_df[subset_df["Occupation"].apply(lambda x: i in x)]["Manner of death"].value_counts())

#visualize the correlation
occupation_manner_df = pd.DataFrame(occupation_manner)
#occupation_manner_df = occupation_manner_df.drop("Unspecified", axis = 1)
plt.figure(figsize=(20,10))
plt.imshow(occupation_manner_df, cmap='hot', interpolation='nearest')
plt.colorbar()
plt.title("Correlation between manner of death and occupation")
plt.show()

# %%
subset_df
# Out:
#                Id                  Name  \
# 0             Q42         Douglas Adams
# 1             Q91       Abraham Lincoln
# 3            Q296          Claude Monet
# 5            Q303         Elvis Presley
# 7            Q346    Louis IX of France
# ...           ...                   ...
# 760380  Q75992692      Daniela Carrasco
# 760412  Q76161186         Sara Champion
# 760518  Q76479205         Věra Kučerová
# 760612  Q76857201      Dolores Millanes
# 760641  Q76995470  David Hillhouse Buel
#
#                                         Short description       Gender  \
# 0                             English writer and humorist         Male
# 1         16th president of the United States (1809-1865)         Male
# 3                French impressionist painter (1840-1926)         Male
# 5                   American singer and actor (1935–1977)         Male
# 7                                          king of France         Male
# ...                                                   ...          ...
# 760380               Chilean mime died in custody in 2019  Unspecified
# 760412                              British archaeologist       Female
# 760518  verzetstrijdster uit Tsjecho-Slowakije (1923-1...  Unspecified
# 760612                                 baaŋa ŋun nyɛ paɣa       Female
# 760641                                 Union Army officer         Male
#
#                          Country          Occupation  Birth year  Death year  \
# 0                 United Kingdom              [rtis]        1952        2001
# 1       United States of America          [oliticia]        1809        1865
# 3                         France              [rtis]        1840        1926
# 5       United States of America              [rtis]        1935        1977
# 7                         France               [ule]        1214        1270
# ...                          ...                 ...         ...         ...
# 760380                     Chile              [rtis]        1983        2019
# 760412            United Kingdom          [esearche]        1946        2000
# 760518            Czechoslovakia         [nspecifie]        1923        1942
# 760612                     Spain              [rtis]        1859        1906
# 760641  United States of America  [ilitary personne]        1839        1870
#
#            Manner of death  Age of death                 CountryCoordinate  \
# 0           natural causes            49                  ['(54.6, -2.0)']
# 1                 homicide            56         ['(39.828175, -98.5795)']
# 3           natural causes            86                   ['(47.0, 2.0)']
# 5           natural causes            42         ['(39.828175, -98.5795)']
# 7           natural causes            56                   ['(47.0, 2.0)']
# ...                    ...           ...                               ...
# 760380            homicide            36                ['(-33.0, -71.0)']
# 760412      natural causes            54                  ['(54.6, -2.0)']
# 760518  capital punishment            19  ['(50.083333333, 14.416666666)']
# 760612        shipwrecking            47                  ['(40.2, -3.5)']
# 760641            homicide            31         ['(39.828175, -98.5795)']
#
#        AssociatedModernCountry
# 0           ['United Kingdom']
# 1            ['United States']
# 3                   ['France']
# 5            ['United States']
# 7                   ['France']
# ...                        ...
# 760380               ['Chile']
# 760412      ['United Kingdom']
# 760518             ['Czechia']
# 760612               ['Spain']
# 760641       ['United States']
#
# [41799 rows x 12 columns]

# %% [markdown]
# # Start here

# %%
# Count different values for manner of death and occupation
#subset_df["Manner of death"].value_counts()

#create a new dataframe with only the id, name, occupation, manner of death
#df = subset_df[["Id", "Name", "Occupation", "Manner of death"]]
df = subset_df[["Occupation", "Manner of death"]]
# split the occupation column into lists
df["Occupation"] = df["Occupation"].apply(lambda x: x.replace("'", ""))
df["Occupation"] = df["Occupation"].apply(lambda x: x.split(";"))
# Out:
# C:\Users\tomo9\AppData\Local\Temp\ipykernel_10784\4196236824.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Occupation"] = df["Occupation"].apply(lambda x: x.replace("'", ""))
# C:\Users\tomo9\AppData\Local\Temp\ipykernel_10784\4196236824.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Occupation"] = df["Occupation"].apply(lambda x: x.split(";"))

# %%
# remove whitespace character from the occupation column if it starts with one
df["Occupation"] = df["Occupation"].apply(lambda x: [i[1:] if i[0] == " " else i for i in x])
# Out:
# C:\Users\tomo9\AppData\Local\Temp\ipykernel_10784\1803110956.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Occupation"] = df["Occupation"].apply(lambda x: [i[1:] if i[0] == " " else i for i in x])

# %%
df
# Out:
#                   Occupation Manner of death
# 0                   [Artist]  natural causes
# 1               [Politician]        homicide
# 2                   [Artist]     Unspecified
# 3                   [Artist]  natural causes
# 4                   [Artist]     Unspecified
# ...                      ...             ...
# 760675        [Entrepreneur]     Unspecified
# 760676       [Tailor, model]     Unspecified
# 760677  [Military personnel]     Unspecified
# 760678              [Artist]     Unspecified
# 760679              [Artist]     Unspecified
#
# [760680 rows x 2 columns]

# %%
df['Occupation'].iloc[760676]
# Out:
# ['Tailor', 'model']

# %%
# Count different values for manner of death and occupation
print(df["Manner of death"].value_counts())
#drop Unspecified from manner of death and occupation
df = df[df["Manner of death"] != "Unspecified"]
df = df[df["Occupation"].apply(lambda x: "Unspecified" not in x)]
print(df["Manner of death"].value_counts())
df = df.explode('Occupation')
df.head()
#print(df["Occupation"].value_counts())
# Out:
# Manner of death
# Unspecified                                        718881
# natural causes                                      27507
# suicide                                              4324
# accident                                             4248
# homicide                                             3269
#                                                     ...
# diabetes mellitus                                       1
# dysentery                                               1
# strangling                                              1
# accident; 2011 Lokomotiv Yaroslavl air disaster         1
# stomach cancer                                          1
# Name: count, Length: 169, dtype: int64
# Manner of death
# natural causes                                     27237
# suicide                                             4122
# accident                                            4104
# homicide                                            2856
# capital punishment                                  1420
#                                                    ...
# accident; 2011 Lokomotiv Yaroslavl air disaster        1
# underwater diving                                      1
# suicide; substance dependence                          1
# deliberate murder                                      1
# White Terror                                           1
# Name: count, Length: 153, dtype: int64
#    Occupation Manner of death
# 0      Artist  natural causes
# 1  Politician        homicide
# 3      Artist  natural causes
# 5      Artist  natural causes
# 7       Ruler  natural causes

# %%
#only keep manner of death before ; in the manner of death column
df["Manner of death"] = df["Manner of death"].apply(lambda x: x.split(";")[0])
print(df['Manner of death'].value_counts())
# Out:
# Manner of death
# natural causes        28026
# suicide                4329
# accident               4280
# homicide               2975
# capital punishment     1614
#                       ...
# era                       1
# assisted suicide          1
# adhesive bandage          1
# Canserbero                1
# White Terror              1
# Name: count, Length: 108, dtype: int64

# %%
print(df["Occupation"].value_counts())
# Out:
# Occupation
# Artist                  15771
# Politician               6201
# Athlete                  5252
# Researcher               2206
# Military personnel       1890
#                         ...
# County court bailiff        1
# ondist                      1
# Notary                      1
# farmworker                  1
# drafter                     1
# Name: count, Length: 1196, dtype: int64

# %%
print(df["Manner of death"].value_counts())
# Out:
# Manner of death
# natural causes        28026
# suicide                4329
# accident               4280
# homicide               2975
# capital punishment     1614
#                       ...
# era                       1
# assisted suicide          1
# adhesive bandage          1
# Canserbero                1
# White Terror              1
# Name: count, Length: 108, dtype: int64

# %%
# Create mapping from occupation to manner of death
mapping = df.groupby('Occupation')['Manner of death'].value_counts()
mapping = mapping.unstack()
mapping = mapping.fillna(0)
mapping = mapping.astype(int)
mapping
# Out:
# Manner of death    2010 Thai political protests  Action T4  \
# Occupation
# Abbé                                          0          0
# Abolitionist                                  0          0
# Academic                                      0          0
# Accordionist                                  0          0
# Accountant                                    0          0
# ...                                         ...        ...
# water skier                                   0          0
# weather presenter                             0          0
# weightlifter                                  0          0
# winegrower                                    0          0
# youtuber                                      0          0
#
# Manner of death    Atentado para uno suizo Zollinger  Avianca Flight 203  \
# Occupation
# Abbé                                               0                   0
# Abolitionist                                       0                   0
# Academic                                           0                   0
# Accordionist                                       0                   0
# Accountant                                         0                   0
# ...                                              ...                 ...
# water skier                                        0                   0
# weather presenter                                  0                   0
# weightlifter                                       0                   0
# winegrower                                         0                   0
# youtuber                                           0                   0
#
# Manner of death    Battle of Maserfield  Bombing of Berlin in World War II  \
# Occupation
# Abbé                                  0                                  0
# Abolitionist                          0                                  0
# Academic                              0                                  0
# Accordionist                          0                                  0
# Accountant                            0                                  0
# ...                                 ...                                ...
# water skier                           0                                  0
# weather presenter                     0                                  0
# weightlifter                          0                                  0
# winegrower                            0                                  0
# youtuber                              0                                  0
#
# Manner of death    Canserbero  Category:People executed by firing squad  \
# Occupation
# Abbé                        0                                         0
# Abolitionist                0                                         0
# Academic                    0                                         0
# Accordionist                0                                         0
# Accountant                  0                                         0
# ...                       ...                                       ...
# water skier                 0                                         0
# weather presenter           0                                         0
# weightlifter                0                                         0
# winegrower                  0                                         0
# youtuber                    0                                         0
#
# Manner of death    Eastern Front of World War II  Esophageal Cancer  ...  \
# Occupation                                                           ...
# Abbé                                           0                  0  ...
# Abolitionist                                   0                  0  ...
# Academic                                       0                  0  ...
# Accordionist                                   0                  0  ...
# Accountant                                     0                  0  ...
# ...                                          ...                ...  ...
# water skier                                    0                  0  ...
# weather presenter                              0                  0  ...
# weightlifter                                   0                  0  ...
# winegrower                                     0                  0  ...
# youtuber                                       0                  0  ...
#
# Manner of death    torture  tram accident  transition  \
# Occupation
# Abbé                     0              0           0
# Abolitionist             0              0           0
# Academic                 0              0           0
# Accordionist             0              0           0
# Accountant               0              0           0
# ...                    ...            ...         ...
# water skier              0              0           0
# weather presenter        0              0           0
# weightlifter             0              0           0
# winegrower               0              0           0
# youtuber                 0              0           0
#
# Manner of death    type 2 diabetes mellitus  underwater diving  \
# Occupation
# Abbé                                      0                  0
# Abolitionist                              0                  0
# Academic                                  0                  0
# Accordionist                              0                  0
# Accountant                                0                  0
# ...                                     ...                ...
# water skier                               0                  0
# weather presenter                         0                  0
# weightlifter                              0                  0
# winegrower                                0                  0
# youtuber                                  0                  0
#
# Manner of death    unfortunate accident  unnatural death  uterine cancer  war  \
# Occupation
# Abbé                                  0                0               0    0
# Abolitionist                          0                0               0    0
# Academic                              0                0               0    0
# Accordionist                          0                0               0    0
# Accountant                            0                0               0    0
# ...                                 ...              ...             ...  ...
# water skier                           0                0               0    0
# weather presenter                     0                0               0    0
# weightlifter                          0                0               0    0
# winegrower                            0                0               0    0
# youtuber                              0                0               0    0
#
# Manner of death    work accident
# Occupation
# Abbé                           0
# Abolitionist                   0
# Academic                       0
# Accordionist                   0
# Accountant                     0
# ...                          ...
# water skier                    0
# weather presenter              0
# weightlifter                   0
# winegrower                     0
# youtuber                       0
#
# [1196 rows x 108 columns]

# %%
# list the occupation and manner of death of the 20 highest correlation values
correlation = []
for i in range(len(mapping)):
    for j in range(len(mapping.columns)):
        correlation.append(mapping.iloc[i,j])
correlation = np.array(correlation)
correlation = correlation[np.argsort(correlation)[::-1]]
correlation[:20]

# list the respective occupations and manner of death

for i in range(len(mapping)):
    for j in range(len(mapping.columns)):
        if mapping.iloc[i,j] in correlation[:20]:
            print(mapping.index[i], mapping.columns[j], mapping.iloc[i,j])
# Out:
# Artist accident 1120
# Artist homicide 495
# Artist natural causes 12235
# Artist suicide 1709
# Athlete accident 922
# Athlete natural causes 3607
# Athlete suicide 470
# Businessperson natural causes 480
# Journalist natural causes 584
# Military personnel accident 403
# Military personnel capital punishment 265
# Military personnel natural causes 664
# Military personnel suicide 261
# Politician accident 533
# Politician capital punishment 430
# Politician homicide 891
# Politician natural causes 3688
# Politician suicide 588
# Religious figure natural causes 359
# Researcher natural causes 1604

# %%
# find the person who has manner of death "adhesive bandage" and print their occupation and their name
print(subset_df[subset_df["Manner of death"] == "adhesive bandage"]["Occupation"])
print(subset_df[subset_df["Manner of death"] == "adhesive bandage"]["Name"])
# Out:
# 76585    Military personnel
# Name: Occupation, dtype: object
# 76585    Gertrudis Bocanegra
# Name: Name, dtype: object

# %%
# show the line with index 76585
subset_df.iloc[76584]
# Out:
# Id                                                             Q717657
# Name                                                      Øivind Bergh
# Short description          Norwegian conductor, violinist and musician
# Gender                                                            Male
# Country                                                         Norway
# Occupation                                                      Artist
# Birth year                                                        1909
# Death year                                                        1987
# Manner of death                                            Unspecified
# Age of death                                                        78
# CountryCoordinate                                     ['(65.0, 11.0)']
# AssociatedModernCountry                                     ['Norway']
# Name: 76584, dtype: object

# %%
#find correlation between occupation and manner of death in df
occupation_manner = []
for i in occupation:
    occupation_manner.append(df[df["Occupation"].apply(lambda x: i in x)]["Manner of death"].value_counts())

#visualize the correlation and add labels
occupation_manner_df = pd.DataFrame(occupation_manner)
occupation_manner_df = occupation_manner_df.drop("Unspecified", axis = 1)
plt.figure(figsize=(20,10))
plt.imshow(occupation_manner_df, cmap='hot', interpolation='nearest')
plt.colorbar()
plt.title("Correlation between manner of death and occupation")
plt.show()
plt.xticks(np.arange(0, 3, 1), ["Natural", "Unnatural", "Unknown"])
plt.yticks(np.arange(0, 20, 1), occupation_manner_df.index)
plt.xlabel("Manner of death")
plt.ylabel("Occupation")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\tomo9\Documents\00_School\03_DataVis\00_Age\AgeVisualization\DataVizPreProcessing.ipynb Cell 23 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/tomo9/Documents/00_School/03_DataVis/00_Age/AgeVisualization/DataVizPreProcessing.ipynb#X43sZmlsZQ%3D%3D?line=12'>13</a> plt.show()
#      <a href='vscode-notebook-cell:/c%3A/Users/tomo9/Documents/00_School/03_DataVis/00_Age/AgeVisualization/DataVizPreProcessing.ipynb#X43sZmlsZQ%3D%3D?line=13'>14</a> plt.xticks(np.arange(0, 3, 1), ["Natural", "Unnatural", "Unknown"])
# ---> <a href='vscode-notebook-cell:/c%3A/Users/tomo9/Documents/00_School/03_DataVis/00_Age/AgeVisualization/DataVizPreProcessing.ipynb#X43sZmlsZQ%3D%3D?line=14'>15</a> plt.yticks(np.arange(0, 20, 1), occupation_manner_df.index)
#      <a href='vscode-notebook-cell:/c%3A/Users/tomo9/Documents/00_School/03_DataVis/00_Age/AgeVisualization/DataVizPreProcessing.ipynb#X43sZmlsZQ%3D%3D?line=15'>16</a> plt.xlabel("Manner of death")
#      <a href='vscode-notebook-cell:/c%3A/Users/tomo9/Documents/00_School/03_DataVis/00_Age/AgeVisualization/DataVizPreProcessing.ipynb#X43sZmlsZQ%3D%3D?line=16'>17</a> plt.ylabel("Occupation")
#
# File c:\Users\tomo9\anaconda3\envs\dataVis_conda\Lib\site-packages\matplotlib\pyplot.py:2124, in yticks(ticks, labels, minor, **kwargs)
#    2122         l._internal_update(kwargs)
#    2123 else:
# -> 2124     labels_out = ax.set_yticklabels(labels, minor=minor, **kwargs)
#    2126 return locs, labels_out
#
# File c:\Users\tomo9\anaconda3\envs\dataVis_conda\Lib\site-packages\matplotlib\axes\_base.py:73, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      72 def wrapper(self, *args, **kwargs):
# ---> 73     return get_method(self)(*args, **kwargs)
#
# File c:\Users\tomo9\anaconda3\envs\dataVis_conda\Lib\site-packages\matplotlib\_api\deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# File c:\Users\tomo9\anaconda3\envs\dataVis_conda\Lib\site-packages\matplotlib\axis.py:2025, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    2021 elif isinstance(locator, mticker.FixedLocator):
#    2022     # Passing [] as a list of labels is often used as a way to
#    2023     # remove all tick labels, so only error for > 0 labels
#    2024     if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 2025         raise ValueError(
#    2026             "The number of FixedLocator locations"
#    2027             f" ({len(locator.locs)}), usually from a call to"
#    2028             " set_ticks, does not match"
#    2029             f" the number of labels ({len(labels)}).")
#    2030     tickd = {loc: lab for loc, lab in zip(locator.locs, labels)}
#    2031     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (20), usually from a call to set_ticks, does not match the number of labels (99).

# %%
print(mapping)
print(df['occupation_id'])
# Out:
# Index(['Artist', 'Politician', 'Ruler', 'Athlete', 'Researcher', 'Official',
#        'french resistance fighter', 'Sovereign', 'Playwright', 'Game designer',
#        ...
#        'Window cleaning', 'auditor', 'Attorney general', 'Radiographer',
#        'Underwriting', 'city attorney', 'Tour operator', 'Dispatcher',
#        'Intermediary', 'Nephrologist'],
#       dtype='object', length=3380)
# 0           0
# 1           1
# 2           0
# 3           0
# 4           0
#          ...
# 760676    333
# 760676    237
# 760677     19
# 760678      0
# 760679      0
# Name: occupation_id, Length: 772889, dtype: int64

# %%
from scipy.stats import chi2_contingency

contingency_table = pd.crosstab(subset_df['Occupation'], subset_df['Manner of death'])
chi2, p, _, _ = chi2_contingency(contingency_table)

print(f"Chi-square value: {chi2}")
print(f"P-value: {p}")
# Out:
# Chi-square value: 5744517.109525747
# P-value: 0.0

# %%
# Assuming you have calculated a correlation matrix
correlation_matrix = subset_df[['Occupation', 'Manner of death']].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\tomo9\Documents\00_School\03_DataVis\00_Age\AgeVisualization\DataVizPreProcessing.ipynb Cell 17 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/tomo9/Documents/00_School/03_DataVis/00_Age/AgeVisualization/DataVizPreProcessing.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> # Assuming you have calculated a correlation matrix
# ----> <a href='vscode-notebook-cell:/c%3A/Users/tomo9/Documents/00_School/03_DataVis/00_Age/AgeVisualization/DataVizPreProcessing.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a> correlation_matrix = subset_df[['Occupation', 'Manner of death']].corr()
#       <a href='vscode-notebook-cell:/c%3A/Users/tomo9/Documents/00_School/03_DataVis/00_Age/AgeVisualization/DataVizPreProcessing.ipynb#X32sZmlsZQ%3D%3D?line=3'>4</a> plt.figure(figsize=(8, 6))
#       <a href='vscode-notebook-cell:/c%3A/Users/tomo9/Documents/00_School/03_DataVis/00_Age/AgeVisualization/DataVizPreProcessing.ipynb#X32sZmlsZQ%3D%3D?line=4'>5</a> sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
#
# File c:\Users\tomo9\anaconda3\envs\dataVis_conda\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\tomo9\anaconda3\envs\dataVis_conda\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File c:\Users\tomo9\anaconda3\envs\dataVis_conda\Lib\site-packages\pandas\core\internals\managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File c:\Users\tomo9\anaconda3\envs\dataVis_conda\Lib\site-packages\pandas\core\internals\managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Artist'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a contingency table
#contingency_table = pd.crosstab(subset_df['Occupation'], subset_df['Manner of death'])

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(contingency_table, annot=True, cmap='coolwarm', fmt='d')
plt.title('Occupation vs. Manner of Death')
plt.xlabel('Manner of Death')
plt.ylabel('Occupation')
plt.show()
