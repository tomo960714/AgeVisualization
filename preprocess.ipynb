# %% [markdown]
# # Preprocess notebook for Data visualization group project

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import os
import math

# %%
separator = ","
# Read the csv file
df = pd.read_csv('Data/ages_dataset.csv',sep=separator)

# %% [markdown]
# #TODO: Compare descriptions to list of countries to find countries
# #TODO: Figure out a way to specify gender based on name

# %%
df.head()
# Out:
#      Id                     Name  \
# 0   Q23        George Washington
# 1   Q42            Douglas Adams
# 2   Q91          Abraham Lincoln
# 3  Q254  Wolfgang Amadeus Mozart
# 4  Q255     Ludwig van Beethoven
#
#                                  Short description Gender  \
# 0   1st president of the United States (1732–1799)   Male
# 1                      English writer and humorist   Male
# 2  16th president of the United States (1809-1865)   Male
# 3        Austrian composer of the Classical period   Male
# 4           German classical and romantic composer   Male
#
#                                              Country  Occupation  Birth year  \
# 0  United States of America; Kingdom of Great Bri...  Politician        1732
# 1                                     United Kingdom      Artist        1952
# 2                           United States of America  Politician        1809
# 3    Archduchy of Austria; Archbishopric of Salzburg      Artist        1756
# 4                 Holy Roman Empire; Austrian Empire      Artist        1770
#
#    Death year Manner of death  Age of death
# 0      1799.0  natural causes          67.0
# 1      2001.0  natural causes          49.0
# 2      1865.0        homicide          56.0
# 3      1791.0             NaN          35.0
# 4      1827.0             NaN          57.0

# %%
def split2list(df,column,separator=','):
    df[column] = df[column].str.split(separator)
    return df

#find gender in description
def update_column(row):
    male_list=["boy","male","lord"]
    female_list=["girl","female","lady"]
    if row["Gender"] == "" and any(word in row["description"] for word in male_list):
        return "Male"
    else:
        return row["Gender"]

    if row["Gender"] == "" and any(word in row["description"] for word in female_list):
        return "Female"
    else:
        return row["Gender"]

def float2int(row,column):
    #print(row[column])
    if row[column] == "":
        return row[column]
    elif isinstance(row[column], float) and not math.isnan(row[column]):
        return int(row[column])
    elif isinstance(row[column], int) and not math.isnan(row[column]):
        return int(row[column])
    else:
        return "NaN"

# %%
df["Gender"] = df.apply(update_column, axis=1)
df["Birth year"] = df.apply(float2int, axis=1,column="Birth year")
df["Death year"] = df.apply(float2int, axis=1,column="Death year")
df["Age of death"] = df.apply(float2int, axis=1,column="Age of death")

# %%
df.head()
# Out:
#      Id                     Name  \
# 0   Q23        George Washington
# 1   Q42            Douglas Adams
# 2   Q91          Abraham Lincoln
# 3  Q254  Wolfgang Amadeus Mozart
# 4  Q255     Ludwig van Beethoven
#
#                                  Short description Gender  \
# 0   1st president of the United States (1732–1799)   Male
# 1                      English writer and humorist   Male
# 2  16th president of the United States (1809-1865)   Male
# 3        Austrian composer of the Classical period   Male
# 4           German classical and romantic composer   Male
#
#                                              Country  Occupation  Birth year  \
# 0  United States of America; Kingdom of Great Bri...  Politician        1732
# 1                                     United Kingdom      Artist        1952
# 2                           United States of America  Politician        1809
# 3    Archduchy of Austria; Archbishopric of Salzburg      Artist        1756
# 4                 Holy Roman Empire; Austrian Empire      Artist        1770
#
#   Death year Manner of death Age of death  \
# 0       1799  natural causes           67
# 1       2001  natural causes           49
# 2       1865        homicide           56
# 3       1791             NaN           35
# 4       1827             NaN           57
#
#                   Associated Countries  \
# 0  ['United Kingdom', 'United States']
# 1                   ['United Kingdom']
# 2                    ['United States']
# 3                          ['Austria']
# 4                 ['Austria', 'Italy']
#
#            Associated Country Coordinates (Lat/Lon)  \
# 0  [(55.378051, -3.435973), (37.09024, -95.712891)]
# 1                          [(55.378051, -3.435973)]
# 2                          [(37.09024, -95.712891)]
# 3                          [(47.516231, 14.550072)]
# 4    [(47.516231, 14.550072), (41.87194, 12.56738)]
#
#   Associated Country Life Expectancy
# 0                       [81.3, 78.5]
# 1                             [81.3]
# 2                             [78.5]
# 3                             [81.6]
# 4                       [81.6, 82.9]

# %%
#show unique occupations in df
df["Occupation"].unique()

#count the number of unique occupations
len(df["Occupation"].unique())
# Out:
# 9314

# %%
# fill missing occupation with "Unspecified"
df["Occupation"].fillna("Unspecified", inplace = True)

# %%
df
# Out:
#                 Id                     Name  \
# 0              Q23        George Washington
# 1              Q42            Douglas Adams
# 2              Q91          Abraham Lincoln
# 3             Q254  Wolfgang Amadeus Mozart
# 4             Q255     Ludwig van Beethoven
# ...            ...                      ...
# 1223004  Q77247326    Marie-Fortunée Besson
# 1223005  Q77249504              Ron Thorsen
# 1223006  Q77249818       Diether Todenhagen
# 1223007  Q77253909  Reginald Oswald Pearson
# 1223008  Q77254864             Horst Lerche
#
#                                          Short description Gender  \
# 0           1st president of the United States (1732–1799)   Male
# 1                              English writer and humorist   Male
# 2          16th president of the United States (1809-1865)   Male
# 3                Austrian composer of the Classical period   Male
# 4                   German classical and romantic composer   Male
# ...                                                    ...    ...
# 1223004                            Frans model (1907-1996)    NaN
# 1223005        xugador de baloncestu canadianu (1948–2004)    NaN
# 1223006  German navy officer and world war II U-boat co...    NaN
# 1223007  English artist, working in stained glass, prin...   Male
# 1223008                                     German painter   Male
#
#                                                    Country  \
# 0        United States of America; Kingdom of Great Bri...
# 1                                           United Kingdom
# 2                                 United States of America
# 3          Archduchy of Austria; Archbishopric of Salzburg
# 4                       Holy Roman Empire; Austrian Empire
# ...                                                    ...
# 1223004                                             France
# 1223005                   Canada; United States of America
# 1223006                                            Germany
# 1223007                                     United Kingdom
# 1223008                                            Germany
#
#                  Occupation  Birth year Death year Manner of death  \
# 0                Politician        1732       1799  natural causes
# 1                    Artist        1952       2001  natural causes
# 2                Politician        1809       1865        homicide
# 3                    Artist        1756       1791             NaN
# 4                    Artist        1770       1827             NaN
# ...                     ...         ...        ...             ...
# 1223004       Tailor; model        1907       1996             NaN
# 1223005             Athlete        1948       2004             NaN
# 1223006  Military personnel        1920       1944             NaN
# 1223007              Artist        1887       1915             NaN
# 1223008              Artist        1938       2017             NaN
#
#         Age of death                 Associated Countries  \
# 0                 67  ['United Kingdom', 'United States']
# 1                 49                   ['United Kingdom']
# 2                 56                    ['United States']
# 3                 35                          ['Austria']
# 4                 57                 ['Austria', 'Italy']
# ...              ...                                  ...
# 1223004           89                           ['France']
# 1223005           56          ['Canada', 'United States']
# 1223006           24                          ['Germany']
# 1223007           28                   ['United Kingdom']
# 1223008           79                          ['Germany']
#
#                   Associated Country Coordinates (Lat/Lon)  \
# 0         [(55.378051, -3.435973), (37.09024, -95.712891)]
# 1                                 [(55.378051, -3.435973)]
# 2                                 [(37.09024, -95.712891)]
# 3                                 [(47.516231, 14.550072)]
# 4           [(47.516231, 14.550072), (41.87194, 12.56738)]
# ...                                                    ...
# 1223004                            [(46.227638, 2.213749)]
# 1223005  [(56.130366, -106.346771), (37.09024, -95.7128...
# 1223006                           [(51.165691, 10.451526)]
# 1223007                           [(55.378051, -3.435973)]
# 1223008                           [(51.165691, 10.451526)]
#
#         Associated Country Life Expectancy
# 0                             [81.3, 78.5]
# 1                                   [81.3]
# 2                                   [78.5]
# 3                                   [81.6]
# 4                             [81.6, 82.9]
# ...                                    ...
# 1223004                             [82.5]
# 1223005                       [81.9, 78.5]
# 1223006                             [80.9]
# 1223007                             [81.3]
# 1223008                             [80.9]
#
# [1223009 rows x 13 columns]

# %%
#show me the rows where the occupation is "Unspecified"
df[df["Occupation"] == "Unspecified"]
# Out:
#                 Id                      Name  \
# 299          Q4291              Ante Bilobrk
# 361       Q3611993       Issa Annamoradnejad
# 1325        Q18715        Philip of Burgundy
# 1392        Q20575  Johann Friedrich Minssen
# 1458        Q22606               Peter Blume
# ...            ...                       ...
# 1222978  Q77035403              Daniel Ježek
# 1222988  Q77073371          David L. Shapiro
# 1222994  Q77127983            Robert Jolidon
# 1222995  Q77188843              Hilary Stagg
# 1222998  Q77217025         Peter Albrechtsen
#
#                                          Short description Gender  \
# 299                            national hero of Yugoslavia   Male
# 361                                Creator of this dataset   Male
# 1325     Count of Auvergne and Boulogne,heir of Duchy o...   Male
# 1392                                                author   Male
# 1458                      a mascot of the city of Mannheim   Male
# ...                                                    ...    ...
# 1222978                ondernemer uit Tsjechië (1977-2010)   Male
# 1222988                             American legal scholar    NaN
# 1222994                                        (1909-1953)   Male
# 1222995                                   American harpist    NaN
# 1222998                           grönländischer Landesrat   Male
#
#                           Country   Occupation  Birth year Death year  \
# 299                           NaN  Unspecified        1919       1943
# 361                           NaN  Unspecified        1992        NaN
# 1325                       France  Unspecified        1323       1346
# 1392                          NaN  Unspecified        1823       1901
# 1458                      Germany  Unspecified        1875       1940
# ...                           ...          ...         ...        ...
# 1222978            Czech Republic  Unspecified        1977       2010
# 1222988  United States of America  Unspecified        1932       2019
# 1222994               Switzerland  Unspecified        1909       1953
# 1222995  United States of America  Unspecified        1957       1999
# 1222998                       NaN  Unspecified        1891       1929
#
#         Manner of death Age of death Associated Countries  \
# 299                 NaN           24                  NaN
# 361                 NaN          NaN                  NaN
# 1325           accident           23           ['France']
# 1392                NaN           78                  NaN
# 1458                NaN           65          ['Germany']
# ...                 ...          ...                  ...
# 1222978             NaN           33   ['Czech Republic']
# 1222988             NaN           87    ['United States']
# 1222994             NaN           44      ['Switzerland']
# 1222995             NaN           42    ['United States']
# 1222998             NaN           38                  NaN
#
#         Associated Country Coordinates (Lat/Lon)  \
# 299                                          NaN
# 361                                          NaN
# 1325                     [(46.227638, 2.213749)]
# 1392                                         NaN
# 1458                    [(51.165691, 10.451526)]
# ...                                          ...
# 1222978                 [(49.817492, 15.472962)]
# 1222988                 [(37.09024, -95.712891)]
# 1222994                  [(46.818188, 8.227512)]
# 1222995                 [(37.09024, -95.712891)]
# 1222998                                      NaN
#
#         Associated Country Life Expectancy
# 299                                    NaN
# 361                                    NaN
# 1325                                [82.5]
# 1392                                   NaN
# 1458                                [80.9]
# ...                                    ...
# 1222978                             [79.0]
# 1222988                             [78.5]
# 1222994                             [83.6]
# 1222995                             [78.5]
# 1222998                                NaN
#
# [206914 rows x 13 columns]

# %%
#Count NaN values in diff columns
# count the number of Nan in the column "gender"
print(f'Nr. of missing values in gender: {len(df[df["Gender"].isna()])}')
print(f'Nr. of missing values in countries: {len(df[df["Country"].isna()])}')
print(f'Nr. of missing values in associated countries: {len(df[df["Associated Countries"].isna()])}')
# Out:
# Nr. of missing values in gender: 133646
# Nr. of missing values in countries: 335509
# Nr. of missing values in associated countries: 368693

# %%
# count unique manner of deaths
len(df["Manner of death"].unique())
# Out:
# 207

# %%
len(df["Manner of death"].isna())

# %%
#Show me the rows where the occupation is "Fencer" and the country is "Hungary" and print all their names
df[(df["Occupation"] == "Fencer") & (df["Country"] == "Hungary")].to_csv("Data/fencer_hungary.csv",index=False)

# %%
separator = ","
# Read the csv file
df = pd.read_csv('Data/fencer_hungary.csv',sep=separator)

# %%
df
# Out:
#            Id                    Name                      Short description  \
# 0      Q26246  Gyöngyi Szalay-Horváth                       Hungarian fencer
# 1      Q27604    István Lichteneckert                                 fencer
# 2     Q165804            Dezső Földes                       Hungarian fencer
# 3     Q186236          Csaba Fenyvesi  Hungarian fencer and Olympic champion
# 4     Q219016  Zoltán Ozoray Schenker                       Hungarian fencer
# ..        ...                     ...                                    ...
# 74   Q6321136         József Komatits                       Hungarian fencer
# 75   Q7264034               Pál Pajzs                                 fencer
# 76   Q7800512       Tibor Székelyhidy                                 fencer
# 77  Q16014013   István Bezegh-Huszágh                       Hungarian fencer
# 78  Q16146759             Jenő Apáthy                                 fencer
#
#     Gender  Country Occupation  Birth year  Death year Manner of death  \
# 0   Female  Hungary     Fencer        1968        2017             NaN
# 1     Male  Hungary     Fencer        1892        1929             NaN
# 2     Male  Hungary     Fencer        1880        1950             NaN
# 3     Male  Hungary     Fencer        1943        2015             NaN
# 4     Male  Hungary     Fencer        1880        1966             NaN
# ..     ...      ...        ...         ...         ...             ...
# 74    Male  Hungary     Fencer        1950        2007             NaN
# 75    Male  Hungary     Fencer        1886        1950             NaN
# 76    Male  Hungary     Fencer        1904        1989             NaN
# 77    Male  Hungary     Fencer        1913        1998             NaN
# 78    Male  Hungary     Fencer        1880        1939             NaN
#
#     Age of death Associated Countries  \
# 0             49          ['Hungary']
# 1             37          ['Hungary']
# 2             70          ['Hungary']
# 3             72          ['Hungary']
# 4             86          ['Hungary']
# ..           ...                  ...
# 74            57          ['Hungary']
# 75            64          ['Hungary']
# 76            85          ['Hungary']
# 77            85          ['Hungary']
# 78            59          ['Hungary']
#
#    Associated Country Coordinates (Lat/Lon) Associated Country Life Expectancy
# 0                  [(47.162494, 19.503304)]                             [75.8]
# 1                  [(47.162494, 19.503304)]                             [75.8]
# 2                  [(47.162494, 19.503304)]                             [75.8]
# 3                  [(47.162494, 19.503304)]                             [75.8]
# 4                  [(47.162494, 19.503304)]                             [75.8]
# ..                                      ...                                ...
# 74                 [(47.162494, 19.503304)]                             [75.8]
# 75                 [(47.162494, 19.503304)]                             [75.8]
# 76                 [(47.162494, 19.503304)]                             [75.8]
# 77                 [(47.162494, 19.503304)]                             [75.8]
# 78                 [(47.162494, 19.503304)]                             [75.8]
#
# [79 rows x 13 columns]
